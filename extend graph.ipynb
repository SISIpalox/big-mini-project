# %%
from fractions import Fraction

def find_sequence_length_greater_than_one(x):
    total = Fraction(0)
    n = 0  # Starting index for summation
    
    while total <= 1:
        total += Fraction(1, (x + 3*n))
        n += 1  # Increment to add the next term in the sequence

    return n  # Return the count of terms needed to exceed the sum of 1

# Calculate the length of the sequence for x values from 1 to 10 as examples
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}
sequence_lengths_for_one
# Out:
# {1: 2,
#  2: 6,
#  3: 11,
#  4: 17,
#  5: 23,
#  6: 30,
#  7: 36,
#  8: 42,
#  9: 49,
#  10: 55,
#  11: 61,
#  12: 68,
#  13: 74,
#  14: 80,
#  15: 87,
#  16: 93,
#  17: 99,
#  18: 106,
#  19: 112,
#  20: 118,
#  21: 125,
#  22: 131,
#  23: 137,
#  24: 144,
#  25: 150,
#  26: 156,
#  27: 163,
#  28: 169,
#  29: 176,
#  30: 182,
#  31: 188,
#  32: 195,
#  33: 201,
#  34: 207,
#  35: 214,
#  36: 220,
#  37: 226,
#  38: 233,
#  39: 239,
#  40: 245,
#  41: 252,
#  42: 258,
#  43: 265,
#  44: 271,
#  45: 277,
#  46: 284,
#  47: 290,
#  48: 296,
#  49: 303,
#  50: 309,
#  51: 315,
#  52: 322,
#  53: 328,
#  54: 335,
#  55: 341,
#  56: 347,
#  57: 354,
#  58: 360,
#  59: 366,
#  60: 373,
#  61: 379,
#  62: 385,
#  63: 392,
#  64: 398,
#  65: 405,
#  66: 411,
#  67: 417,
#  68: 424,
#  69: 430,
#  70: 436,
#  71: 443,
#  72: 449,
#  73: 455,
#  74: 462,
#  75: 468,
#  76: 474,
#  77: 481,
#  78: 487,
#  79: 494,
#  80: 500,
#  81: 506,
#  82: 513,
#  83: 519,
#  84: 525,
#  85: 532,
# ...

# %%
# It appears the plotting library matplotlib was not imported in the provided snippet.
# Let's import matplotlib and plot the graph again.

import matplotlib.pyplot as plt

# Assuming the sequence_lengths calculation was successful, let's plot the graph.
# x_values and sequence_lengths are already defined from the earlier description.

# Generate the sequence_lengths again in the context of this execution environment
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}

# Extracting the sequence lengths as a list for plotting
sequence_lengths = list(sequence_lengths_for_one.values())

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 100), sequence_lengths, marker='o', linestyle='-', color='blue')
plt.title('Number of Terms Required for Sum > 1 by Starting Value x')
plt.xlabel('Starting Value x')
plt.ylabel('Number of Terms Required')
plt.grid(True)
plt.show()

# %%
from fractions import Fraction

def find_sequence_length_greater_than_one(x):
    total = Fraction(0)
    n = 0  # Starting index for summation
    
    while total <= 1:
        total += Fraction(1, (x + 4*n))
        n += 1  # Increment to add the next term in the sequence

    return n  # Return the count of terms needed to exceed the sum of 1

# Calculate the length of the sequence for x values from 1 to 10 as examples
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}
sequence_lengths_for_one
# It appears the plotting library matplotlib was not imported in the provided snippet.
# Let's import matplotlib and plot the graph again.

import matplotlib.pyplot as plt

# Assuming the sequence_lengths calculation was successful, let's plot the graph.
# x_values and sequence_lengths are already defined from the earlier description.

# Generate the sequence_lengths again in the context of this execution environment
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}

# Extracting the sequence lengths as a list for plotting
sequence_lengths = list(sequence_lengths_for_one.values())

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 100), sequence_lengths, marker='o', linestyle='-', color='blue')
plt.title('Number of Terms Required for Sum > 1 by Starting Value x')
plt.xlabel('Starting Value x')
plt.ylabel('Number of Terms Required')
plt.grid(True)
plt.show()

# %%
from fractions import Fraction

def find_sequence_length_greater_than_one(x):
    total = Fraction(0)
    n = 0  # Starting index for summation
    
    while total <= 1:
        total += Fraction(1, (x + 5*n))
        n += 1  # Increment to add the next term in the sequence

    return n  # Return the count of terms needed to exceed the sum of 1

# Calculate the length of the sequence for x values from 1 to 10 as examples
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}
sequence_lengths_for_one
# It appears the plotting library matplotlib was not imported in the provided snippet.
# Let's import matplotlib and plot the graph again.

import matplotlib.pyplot as plt

# Assuming the sequence_lengths calculation was successful, let's plot the graph.
# x_values and sequence_lengths are already defined from the earlier description.

# Generate the sequence_lengths again in the context of this execution environment
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}

# Extracting the sequence lengths as a list for plotting
sequence_lengths = list(sequence_lengths_for_one.values())

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 100), sequence_lengths, marker='o', linestyle='-', color='blue')
plt.title('Number of Terms Required for Sum > 1 by Starting Value x')
plt.xlabel('Starting Value x')
plt.ylabel('Number of Terms Required')
plt.grid(True)
plt.show()

# %%
from fractions import Fraction

def find_sequence_length_greater_than_one(x):
    total = Fraction(0)
    n = 0  # Starting index for summation
    
    while total <= 1:
        total += Fraction(1, (x + 6*n))
        n += 1  # Increment to add the next term in the sequence

    return n  # Return the count of terms needed to exceed the sum of 1

# Calculate the length of the sequence for x values from 1 to 10 as examples
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}
sequence_lengths_for_one
# It appears the plotting library matplotlib was not imported in the provided snippet.
# Let's import matplotlib and plot the graph again.

import matplotlib.pyplot as plt

# Assuming the sequence_lengths calculation was successful, let's plot the graph.
# x_values and sequence_lengths are already defined from the earlier description.

# Generate the sequence_lengths again in the context of this execution environment
sequence_lengths_for_one = {x: find_sequence_length_greater_than_one(x) for x in range(1, 100)}

# Extracting the sequence lengths as a list for plotting
sequence_lengths = list(sequence_lengths_for_one.values())

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 100), sequence_lengths, marker='o', linestyle='-', color='blue')
plt.title('Number of Terms Required for Sum > 1 by Starting Value x')
plt.xlabel('Starting Value x')
plt.ylabel('Number of Terms Required')
plt.grid(True)
plt.show()
